# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
orders = pd.read_csv('c:\\users\\chris\\downloads\\machine_learning_lab_unzip\\machine_learning_lab\\data\\orders.csv')

# %%
orders.keys()
# Out:
# Index(['Row.ID', 'Order.ID', 'Order.Date', 'Ship.Date', 'Ship.Mode',
#        'Customer.ID', 'Customer.Name', 'Segment', 'Postal.Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product.ID', 'Category',
#        'Sub.Category', 'Product.Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping.Cost', 'Order.Priority'],
#       dtype='object')

# %%
orders['Sub.Category'].unique
# Out:
# <bound method Series.unique of 0             Phones
# 1             Chairs
# 2             Phones
# 3             Phones
# 4            Copiers
# 5             Phones
# 6             Chairs
# 7             Tables
# 8          Bookcases
# 9             Chairs
# 10               Art
# 11            Tables
# 12            Phones
# 13            Chairs
# 14        Appliances
# 15        Appliances
# 16           Storage
# 17        Appliances
# 18           Copiers
# 19        Appliances
# 20            Tables
# 21           Storage
# 22            Chairs
# 23        Appliances
# 24            Phones
# 25            Tables
# 26            Tables
# 27        Appliances
# 28         Fasteners
# 29            Chairs
#             ...
# 51260     Appliances
# 51261         Phones
# 51262         Phones
# 51263        Binders
# 51264      Envelopes
# 51265         Phones
# 51266          Paper
# 51267     Appliances
# 51268        Binders
# 51269            Art
# 51270         Labels
# ...

# %%
#Problem 1
#Remove $ and , from strings, then convert to float

# %%
orders.Profit = list(map(lambda x: x.replace('$',''), orders.Profit))

# %%
orders.Profit = list(map(lambda x: x.replace(',',''), orders.Profit))

# %%
orders.Profit = list(map(lambda x: float(x), orders.Profit))

# %%
orders.Sales = list(map(lambda x: x.replace('$',''), orders.Sales))

# %%
orders.Sales = list(map(lambda x: x.replace(',',''), orders.Sales))

# %%
orders.Sales = list(map(lambda x: float(x), orders.Sales))

# %%
#Problem 2

# %%
orders['Order.Date'] = pd.to_datetime(orders['Order.Date'])

# %%
orders['Order.Date'][1] < orders['Order.Date'][2]
# Out:
# True

# %%
orders['Order.Month'] = list(map(lambda x: x.month,orders['Order.Date']))

# %%
month_quant = orders(['Quantity','Category']).groupby(orders['Order.Month']).agg(['sum'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-3b97199890b0> in <module>()
# ----> 1 month_quant = orders(['Quantity','Category']).groupby(orders['Order.Month']).agg(['sum'])
#
# TypeError: 'DataFrame' object is not callable

# %%
month_cat.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-535c2ce8010e> in <module>()
# ----> 1 month_cat.plot.bar()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, **kwds)
#    2486         axes : matplotlib.AxesSubplot or np.array of them
#    2487         """
# -> 2488         return self(kind='bar', **kwds)
#    2489
#    2490     def barh(self, **kwds):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2451                            colormap=colormap, table=table, yerr=yerr,
#    2452                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2453                            **kwds)
# ...

# %%
#Problem 3

# %%
returns_df = pd.read_csv('c:\\users\\chris\\downloads\\machine_learning_lab_unzip\\machine_learning_lab\\data\\returns.csv')

# %%
returns_df.keys()
# Out:
# Index(['Returned', 'Order ID', 'Region'], dtype='object')

# %%
orders['Order.ID']
# Out:
# 0        CA-2014-AB10015140-41954
# 1          IN-2014-JR162107-41675
# 2          IN-2014-CR127307-41929
# 3         ES-2014-KM1637548-41667
# 4         SG-2014-RH9495111-41948
# 5          IN-2014-JM156557-41818
# 6         IN-2012-TS2134092-41219
# 7         IN-2013-MB1808592-41378
# 8        CA-2014-AB10015140-41954
# 9        CA-2012-AB10015140-40974
# 10       CA-2012-AB10015140-40974
# 11         ID-2013-AJ107801-41383
# 12        SA-2012-MM7260110-41269
# 13        MX-2013-VF2171518-41591
# 14        IN-2014-PF1912027-41796
# 15        ES-2015-BP1118545-42216
# 16       CA-2012-AB10015140-40958
# 17        ES-2015-PJ1883564-42255
# 18         IN-2015-JS156857-42035
# 19        TZ-2015-RH9555129-42343
# 20         PL-2013-AB600103-41494
# 21       CA-2012-AB10015140-40974
# 22        IN-2012-JK1532527-41030
# 23       ES-2014-LB16795139-41697
# 24        US-2015-NP1832582-42216
# 25        MX-2015-VD2167039-42252
# 26       IN-2012-PB19210127-41259
# ...

# %%
returns = pd.merge(returns_df,orders, left_on='Order ID',right_on='Order.ID', how='left')

# %%
returns.Profit.sum()
# Out:
# 61370.74999999992

# %%
returns.keys()
# Out:
# Index(['Returned', 'Order ID', 'Region_x', 'Row.ID', 'Order.ID', 'Order.Date',
#        'Ship.Date', 'Ship.Mode', 'Customer.ID', 'Customer.Name', 'Segment',
#        'Postal.Code', 'City', 'State', 'Country', 'Region_y', 'Market',
#        'Product.ID', 'Category', 'Sub.Category', 'Product.Name', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Shipping.Cost', 'Order.Priority',
#        'Order.Month'],
#       dtype='object')

# %%
returns.groupby('Order ID').agg('sum')
# Out:
#                           Row.ID  Postal.Code    Sales  Quantity  Discount  \
# Order ID
# AE-2014-MY7380138-42004    97235          NaN    23.64         3     1.400
# AG-2013-PO88653-41634      97323          NaN  1932.24         7     0.000
# AG-2014-CM21603-41755      42400          NaN    43.05         1     0.000
# AG-2014-CP20853-41889     100657          NaN    84.72         4     0.000
# AG-2014-RD95853-41712      90649          NaN    64.38         3     0.000
# AJ-2013-SG108909-41580     85613          NaN   453.24         5     0.000
# AL-2012-EM38252-41213     133380          NaN    77.16         4     0.000
# AL-2012-SC102302-40970     42964          NaN  1619.10        10     0.000
# AO-2013-JE57454-41544     153147          NaN   499.23         4     0.000
# AO-2013-SF102004-41628     45252          NaN   298.62         6     0.000
# BN-2012-RW963015-41216     98481          NaN   546.00         4     0.000
# ...
